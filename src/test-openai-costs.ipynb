# %%
import pandas as pd
import jinja2  # Templating library (prompt templates)
from dotenv import load_dotenv
from openai import OpenAI
import tiktoken  # Estimate OpenAI tokens

load_dotenv("../.env")
client = OpenAI()

# %%
df = pd.read_csv("../data/ASAP2_new_IN_data_only.csv")
df
# Out:
#                    essay_id  score  \
# 0      AAAOPP13416000019936      4
# 1      AAAOPP13416000055926      5
# 2      AAAOPP13416000005911      3
# 3      AAAOPP13416000019800      3
# 4      AAAOPP13416000019823      4
# ...                     ...    ...
# 11821  AAAOPP13416000218424      1
# 11822  AAAOPP13416000254175      1
# 11823  AAAOPP13416000260386      1
# 11824  AAAOPP13416000292300      1
# 11825  AAAOPP13416000294879      1
#
#                                                full_text    set  pubpriv  \
# 0      Being a Seagoing Cowboy is really fun, but als...   test  private
# 1      To whom ever reads this at the end, you might ...   test   public
# 2      Have you ever wondered about what you might do...  train        0
# 3      I believe that you should join the Seagoing Co...  train        0
# 4      Would you like to participate in the Seagoing ...  train        0
# ...                                                  ...    ...      ...
# 11821  We've been discovering things almost everyday....   test  private
# 11822  In 1976 the queation was and everyone was also...  train        0
# 11823  25 years ago there was a face discovered by na...   test  private
# 11824  The\n\nfirst thing that i should include in my...  train        0
# 11825  I will be talking to you about the face on mar...  train        0
#
#                                               assignment  \
# 0      You have just read the article, 'A Cowboy Who ...
# 1      You have just read the article, 'A Cowboy Who ...
# 2      You have just read the article, 'A Cowboy Who ...
# 3      You have just read the article, 'A Cowboy Who ...
# 4      You have just read the article, 'A Cowboy Who ...
# ...                                                  ...
# 11821  You have read the article 'Unmasking the Face ...
# 11822  You have read the article 'Unmasking the Face ...
# 11823  You have read the article 'Unmasking the Face ...
# 11824  You have read the article 'Unmasking the Face ...
# 11825  You have read the article 'Unmasking the Face ...
#
#                          prompt_name      economically_disadvantaged  \
# 0      "A Cowboy Who Rode the Waves"      Economically disadvantaged
# 1      "A Cowboy Who Rode the Waves"  Not economically disadvantaged
# 2      "A Cowboy Who Rode the Waves"      Economically disadvantaged
# 3      "A Cowboy Who Rode the Waves"  Not economically disadvantaged
# 4      "A Cowboy Who Rode the Waves"  Not economically disadvantaged
# ...                              ...                             ...
# 11821               The Face on Mars      Economically disadvantaged
# 11822               The Face on Mars  Not economically disadvantaged
# 11823               The Face on Mars  Not economically disadvantaged
# 11824               The Face on Mars  Not economically disadvantaged
# 11825               The Face on Mars      Economically disadvantaged
#
#                  student_disability_status ell_status  \
# 0      Not identified as having disability         No
# 1      Not identified as having disability         No
# 2      Not identified as having disability         No
# 3      Not identified as having disability         No
# 4      Not identified as having disability         No
# ...                                    ...        ...
# 11821  Not identified as having disability         No
# 11822  Not identified as having disability         No
# 11823  Not identified as having disability         No
# 11824  Not identified as having disability         No
# 11825      Identified as having disability         No
#
#                 race_ethnicity gender  grade_level  essay_word_count source  \
# 0       Black/African American      M            6             538.0     MI
# 1              Hispanic/Latino      F            6             367.0     MI
# 2      Two or more races/Other      F            6             498.0     MI
# 3       Asian/Pacific Islander      F            6             317.0     MI
# 4       Asian/Pacific Islander      F            6             443.0     MI
# ...                        ...    ...          ...               ...    ...
# 11821   Black/African American      M            8             259.0     MI
# 11822  Two or more races/Other      M            8             226.0     MI
# 11823   Black/African American      M            8             163.0     MI
# 11824   Black/African American      F            8             292.0     MI
# 11825                    White      M            8             191.0     MI
#
#                  task
# 0      Text dependent
# 1      Text dependent
# 2      Text dependent
# 3      Text dependent
# 4      Text dependent
# ...               ...
# 11821  Text dependent
# 11822  Text dependent
# 11823  Text dependent
# 11824  Text dependent
# 11825  Text dependent
#
# [11826 rows x 16 columns]

# %%
environment = jinja2.Environment(loader=jinja2.FileSystemLoader("prompt_templates"))
template = environment.get_template("scoring_prompt.jinja2")

# %%
sample = df.sample(1)

print("Original Score: ", sample["score"].item())

# response = client.chat.completions.create(
#     model="o3-mini-2025-01-31",
#     messages=[
#         {
#             "role": "user", 
#             "content": template.render(sample.to_dict(orient="records")[0])
#         }
#     ],
#     response_format={
#         "type": "json_schema",
#         "json_schema": {
#             "name": "holistic_score_schema",
#             "schema": {
#                 "type": "object",
#                 "properties": {
#                     "score": {
#                         "description": "A single digit from 1-6 representing the holistic core of the essay",
#                         "type": "integer"
#                     },
#                     "additionalProperties": False
#                 }
#             }
#         }
#     }
# )

print(response.choices[0].message.content);
# Out:
# Original Score:  3
# {"score": 3}

# %% [markdown]
# # Construct Batch Input
#
# OpenAI gives us a discount if we send the job as a batch.
#
# Format for batch input is a JSONL file with the following structure:
# ```
# {
#   "custom_id": "request-1",
#   "method": "POST",
#   "url": "/v1/chat/completions",
#   "body": {
#     "model": "gpt-3.5-turbo-0125",
#     "messages": [{
#       "role": "user",
#       "content": "Hello world!"
#     }]
#   }
# }
# ```

# %%
def format_request(custom_id, template_inputs, template, model_name="o3-mini-2025-01-31"):
    return {
        "custom_id": custom_id,
        "method": "POST",
        "url": "/v1/chat/completions",
        "body": {
            "model": "o3-mini-2025-01-31",
            "messages": [{
                "role": "user",
                "content": template.render(**template_inputs)
            }]
        }
    }

batch_input = pd.DataFrame([
    format_request(
        row.essay_id,
        {
            "assignment": row.assignment,
            "full_text": row.full_text,
        },
        template,
    )
    for row in df.itertuples()
])

batch_input.to_json("../data/batch_input.jsonl", orient="records", lines=True)

batch_input
# Out:
#                   custom_id method                   url  \
# 0      AAAOPP13416000019936   POST  /v1/chat/completions
# 1      AAAOPP13416000055926   POST  /v1/chat/completions
# 2      AAAOPP13416000005911   POST  /v1/chat/completions
# 3      AAAOPP13416000019800   POST  /v1/chat/completions
# 4      AAAOPP13416000019823   POST  /v1/chat/completions
# ...                     ...    ...                   ...
# 11821  AAAOPP13416000218424   POST  /v1/chat/completions
# 11822  AAAOPP13416000254175   POST  /v1/chat/completions
# 11823  AAAOPP13416000260386   POST  /v1/chat/completions
# 11824  AAAOPP13416000292300   POST  /v1/chat/completions
# 11825  AAAOPP13416000294879   POST  /v1/chat/completions
#
#                                                     body
# 0      {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 1      {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 2      {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 3      {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 4      {'model': 'o3-mini-2025-01-31', 'messages': [{...
# ...                                                  ...
# 11821  {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 11822  {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 11823  {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 11824  {'model': 'o3-mini-2025-01-31', 'messages': [{...
# 11825  {'model': 'o3-mini-2025-01-31', 'messages': [{...
#
# [11826 rows x 4 columns]

# %% [markdown]
# ## Estimate pricing
#
# This is based on the list price. Actual price should be 50% lower since we are using a batch job.

# %%
def num_tokens_from_body(row, model_name="o3-mini-2025-01-31", split_on=None) -> int:
    """Returns the number of tokens in the messages field of the body column."""
    encoding = tiktoken.encoding_for_model(model_name)
    num_tokens = 0
    for message in row["body"]["messages"]:
        text = message["content"]
        if split_on:
            text = text.split(split_on)[0]
        num_tokens += len(encoding.encode(text))
    return num_tokens

batch_input["token_count"] = batch_input.apply(num_tokens_from_body, axis="columns")
batch_input["static_token_count"] = batch_input.apply(num_tokens_from_body, axis="columns", split_on="```")
batch_input.describe()
# Out:
#         token_count  dynamic_token_count
# count  11826.000000              11826.0
# mean    1350.343903                838.0
# std      157.357335                  0.0
# min     1082.000000                838.0
# 25%     1229.000000                838.0
# 50%     1325.000000                838.0
# 75%     1442.000000                838.0
# max     2388.000000                838.0

# %%
total_input_tokens = batch_input.token_count.sum()
static_input_tokens = batch_input.dynamic_token_count.sum()
dynamic_input_tokens = total_input_tokens - static_input_tokens
dynamic_price = 1.1 / 1_000_000 # Price per token
static_price = .55 / 1_000_000 # Price per cached token

print(f"Price for Static Tokens: ${static_input_tokens * static_price:.2f}")
print(f"Price for Dynamic Tokens: ${dynamic_input_tokens * dynamic_price:.2f}")
print(f"Total Price: ${static_input_tokens * static_price + dynamic_input_tokens * dynamic_price:.2f}")
# Out:
# Price for Static Tokens: $5.45
# Price for Dynamic Tokens: $6.66
# Total Price: $12.12

# %% [markdown]
# ## Creat Batch Job in OpenAI

# %%
batch_input_file = client.files.create(
    file=open("../data/batch_input.jsonl", "rb"),
    purpose="batch"
)
batch_input_file_id = batch_input_file.id
batch_details = client.batches.create(
    input_file_id=batch_input_file_id,
    endpoint="/v1/chat/completions",
    completion_window="24h",
    metadata={
        "description": "ASAP Scoring 1"
    }
)
print(f"batch-id:\n{batch_details.id}\n")
print(batch_details)
# Out:
# file-QpMFaCikP6tBAVVa9vRJhx
# batch-id:
# batch_67cc701c87048190a27935e671f55cd7
# Batch(id='batch_67cc701c87048190a27935e671f55cd7', completion_window='24h', created_at=1741451292, endpoint='/v1/chat/completions', input_file_id='file-QpMFaCikP6tBAVVa9vRJhx', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1741537692, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'ASAP Scoring 1'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %%
batch = client.batches.retrieve("batch_67cc701c87048190a27935e671f55cd7")
print(batch)
# Out:
# Batch(id='batch_67cc701c87048190a27935e671f55cd7', completion_window='24h', created_at=1741451292, endpoint='/v1/chat/completions', input_file_id='file-QpMFaCikP6tBAVVa9vRJhx', object='batch', status='in_progress', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1741537692, failed_at=None, finalizing_at=None, in_progress_at=1741451296, metadata={'description': 'ASAP Scoring 1'}, output_file_id=None, request_counts=BatchRequestCounts(completed=8322, failed=0, total=11826))

# %%
file_response = client.files.content("na")
print(file_response.text)
